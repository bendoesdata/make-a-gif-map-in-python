# %%
# load libraries
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
import seaborn as sns
import time
import os
from pysal.esda.mapclassify import Quantiles, Equal_Interval

# %%
# set the filepath and load in a shapefile
fp = "datasets/geo-data/gis-boundaries-london/ESRI/London_Borough_Excluding_MHW.shp"

data = gpd.read_file(fp)

# %%
# check borough names
data.head()
# Out:
#                    NAME   GSS_CODE   HECTARES  NONLD_AREA ONS_INNER SUB_2009  \
# 0  Kingston upon Thames  E09000021   3726.117       0.000         F     None
# 1               Croydon  E09000008   8649.441       0.000         F     None
# 2               Bromley  E09000006  15013.487       0.000         F     None
# 3              Hounslow  E09000018   5658.541      60.755         F     None
# 4                Ealing  E09000009   5554.428       0.000         F     None
#
#   SUB_2006                                           geometry
# 0     None  POLYGON ((516401.6 160201.8, 516407.3 160210.5...
# 1     None  POLYGON ((535009.2 159504.7, 535005.5 159502, ...
# 2     None  POLYGON ((540373.6 157530.4, 540361.2 157551.9...
# 3     None  POLYGON ((521975.8 178100, 521967.7 178096.8, ...
# 4     None  POLYGON ((510253.5 182881.6, 510249.9 182886, ...

# %%
# testing out the data to see how it looks with a cmap
plot = data.plot(column='HECTARES', cmap='OrRd')

fig = plot.get_figure()

# %%
# load in new csv to merge with geodata
df = pd.read_csv("datasets/MPS_Borough_Level_Crime_Historic.csv", header=0, encoding="utf-8")

df.head()
# Out:
#                 borough   major_category                     minor_category  \
# 0  Barking and Dagenham         Burglary             Burglary in a Dwelling
# 1  Barking and Dagenham         Burglary        Burglary in Other Buildings
# 2  Barking and Dagenham  Criminal Damage        Criminal Damage To Dwelling
# 3  Barking and Dagenham  Criminal Damage   Criminal Damage To Motor Vehicle
# 4  Barking and Dagenham  Criminal Damage  Criminal Damage To Other Building
#
#    200801  200802  200803  200804  200805  200806  200807   ...    201603  \
# 0      82      71      87      74      74     103     113   ...        73
# 1      59      68      56      53      57      39      44   ...        32
# 2      79      52      55      73      63      80      73   ...        50
# 3     142     138     118     158     126      96     116   ...        73
# 4      20      19      20      23      16      12      17   ...        21
#
#    201604  201605  201606  201607  201608  201609  201610  201611  201612
# 0      47      77      63      55      54      49      60      73     100
# 1      42      42      47      32      33      45      40      24      19
# 2      36      58      30      48      38      31      29      32      26
# 3      61      81      73      69      68      61      69      67      59
# 4      13      13      18      15      16      11      12      16       8
#
# [5 rows x 111 columns]

# %%
# filter to include only data labeled as 'Violence Against the Person'
filtered = df['major_category'] == 'Violence Against the Person'

violence = df[filtered]

violence

# groupby to get the sum of each by borough
df3 = violence.groupby('borough').sum()

df3.head()
# Out:
#                       200801  200802  200803  200804  200805  200806  200807  \
# borough
# Barking and Dagenham     449     366     415     415     425     485     485
# Barnet                   385     386     413     429     524     475     516
# Bexley                   238     301     286     279     294     299     281
# Brent                    443     423     504     518     599     550     588
# Bromley                  454     413     470     419     473     446     585
#
#                       200808  200809  200810   ...    201603  201604  201605  \
# borough                                        ...
# Barking and Dagenham     481     394     392   ...       557     475     572
# Barnet                   383     383     418   ...       576     634     711
# Bexley                   265     285     290   ...       405     314     369
# Brent                    489     518     590   ...       684     785     865
# Bromley                  469     441     484   ...       529     481     569
#
#                       201606  201607  201608  201609  201610  201611  201612
# borough
# Barking and Dagenham     546     617     522     518     447     500     465
# Barnet                   677     666     661     658     677     613     598
# Bexley                   398     424     342     390     413     411     396
# Brent                    839     787     780     768     817     736     777
# Bromley                  558     627     523     543     606     559     607
#
# [5 rows x 108 columns]

# %%
# then we need to melt the df so it's in tidy format. reshape the table to keep the columns borough, category, year (as variable) and value
melted = pd.melt(violence,  id_vars=['borough','major_category','minor_category'])

melted.head()
# Out:
#                 borough               major_category        minor_category  \
# 0  Barking and Dagenham  Violence Against the Person   Assault with Injury
# 1  Barking and Dagenham  Violence Against the Person        Common Assault
# 2  Barking and Dagenham  Violence Against the Person  Grievous Bodily Harm
# 3  Barking and Dagenham  Violence Against the Person            Harassment
# 4  Barking and Dagenham  Violence Against the Person                Murder
#
#   variable  value
# 0   200801    180
# 1   200801     99
# 2   200801      0
# 3   200801    129
# 4   200801      0

# %%
df2 = melted.groupby('borough').sum()

df2.head()
# Out:
#                       value
# borough
# Barking and Dagenham  44195
# Barnet                47586
# Bexley                30686
# Brent                 65867
# Bromley               47917

# %%
# then let's pivot the dataframe to add on the column 'major_category' and add up the values for each borough by year
crime = melted.pivot_table(values='value', index=['borough','major_category'], columns='variable', aggfunc=np.sum)
crime.columns = crime.columns.get_level_values(0)
crime
# Out:
# variable                                            200801  200802  200803  \
# borough                major_category
# Barking and Dagenham   Violence Against the Person     449     366     415
# Barnet                 Violence Against the Person     385     386     413
# Bexley                 Violence Against the Person     238     301     286
# Brent                  Violence Against the Person     443     423     504
# Bromley                Violence Against the Person     454     413     470
# Camden                 Violence Against the Person     417     452     521
# Croydon                Violence Against the Person     561     532     624
# Ealing                 Violence Against the Person     596     599     625
# Enfield                Violence Against the Person     341     286     333
# Greenwich              Violence Against the Person     559     549     572
# Hackney                Violence Against the Person     520     524     592
# Hammersmith and Fulham Violence Against the Person     389     421     380
# Haringey               Violence Against the Person     442     413     416
# Harrow                 Violence Against the Person     254     219     232
# Havering               Violence Against the Person     216     213     254
# Hillingdon             Violence Against the Person     480     488     508
# Hounslow               Violence Against the Person     448     429     476
# Islington              Violence Against the Person     464     429     491
# Kensington and Chelsea Violence Against the Person     202     228     250
# Kingston upon Thames   Violence Against the Person     191     204     227
# Lambeth                Violence Against the Person     603     628     604
# Lewisham               Violence Against the Person     638     663     740
# Merton                 Violence Against the Person     264     303     277
# Newham                 Violence Against the Person     707     500     617
# Redbridge              Violence Against the Person     318     327     387
# Richmond upon Thames   Violence Against the Person     144     151     160
# Southwark              Violence Against the Person     769     686     715
# Sutton                 Violence Against the Person     227     192     224
# Tower Hamlets          Violence Against the Person     538     484     543
# Waltham Forest         Violence Against the Person     425     397     471
# Wandsworth             Violence Against the Person     433     385     433
# Westminster            Violence Against the Person     713     617     648
#
# variable                                            200804  200805  200806  \
# borough                major_category
# Barking and Dagenham   Violence Against the Person     415     425     485
# Barnet                 Violence Against the Person     429     524     475
# Bexley                 Violence Against the Person     279     294     299
# Croydon                Violence Against the Person    1021     914     891
# Ealing                 Violence Against the Person     886     844     829
# Enfield                Violence Against the Person     679     613     640
# Greenwich              Violence Against the Person     798     716     787
# Hackney                Violence Against the Person     842     768     792
# Hammersmith and Fulham Violence Against the Person     533     568     507
# Haringey               Violence Against the Person     821     744     730
# Harrow                 Violence Against the Person     408     346     369
# Havering               Violence Against the Person     535     482     515
# Hillingdon             Violence Against the Person     748     673     644
# Hounslow               Violence Against the Person     648     619     608
# Islington              Violence Against the Person     760     648     597
# Kensington and Chelsea Violence Against the Person     416     639     391
# Kingston upon Thames   Violence Against the Person     281     278     296
# Lambeth                Violence Against the Person    1027     957     921
# Lewisham               Violence Against the Person     777     719     725
# Merton                 Violence Against the Person     418     349     341
# Newham                 Violence Against the Person     893     813     743
# Redbridge              Violence Against the Person     612     588     508
# Richmond upon Thames   Violence Against the Person     303     262     284
# Southwark              Violence Against the Person     866     827     806
# Sutton                 Violence Against the Person     344     266     313
# Tower Hamlets          Violence Against the Person     973     797     854
# Waltham Forest         Violence Against the Person     722     595     598
# Wandsworth             Violence Against the Person     690     510     586
# Westminster            Violence Against the Person    1152    1006     994
#
# variable                                            201610  201611  201612
# borough                major_category
# Barking and Dagenham   Violence Against the Person     447     500     465
# Barnet                 Violence Against the Person     677     613     598
# Bexley                 Violence Against the Person     413     411     396
# Brent                  Violence Against the Person     817     736     777
# Bromley                Violence Against the Person     606     559     607
# Camden                 Violence Against the Person     636     593     675
# Croydon                Violence Against the Person     904     873     862
# Ealing                 Violence Against the Person     793     683     773
# Enfield                Violence Against the Person     647     564     566
# Greenwich              Violence Against the Person     719     679     696
# Hackney                Violence Against the Person     763     706     716
# Hammersmith and Fulham Violence Against the Person     506     484     523
# Haringey               Violence Against the Person     720     704     699
# Harrow                 Violence Against the Person     367     355     333
# Havering               Violence Against the Person     480     490     508
# Hillingdon             Violence Against the Person     669     567     622
# Hounslow               Violence Against the Person     698     640     589
# Islington              Violence Against the Person     647     585     632
# Kensington and Chelsea Violence Against the Person     356     381     356
# Kingston upon Thames   Violence Against the Person     259     247     296
# Lambeth                Violence Against the Person     868     828     798
# Lewisham               Violence Against the Person     742     763     758
# Merton                 Violence Against the Person     314     298     303
# Newham                 Violence Against the Person     839     817     819
# Redbridge              Violence Against the Person     523     479     484
# Richmond upon Thames   Violence Against the Person     268     251     249
# Southwark              Violence Against the Person     777     743     738
# Sutton                 Violence Against the Person     293     314     300
# Tower Hamlets          Violence Against the Person     879     760     747
# Waltham Forest         Violence Against the Person     608     592     620
# Wandsworth             Violence Against the Person     629     533     536
# Westminster            Violence Against the Person     999     926    1005
#
# [32 rows x 108 columns]

# %%
# join the geodataframe with the cleaned up csv dataframe
merged1 = data.set_index('NAME').join(df3)

merged1 = merged1.reindex(merged1.index.rename('borough'))

merged1.max
# Out:
# <bound method DataFrame.max of                          GSS_CODE   HECTARES  NONLD_AREA ONS_INNER SUB_2009  \
# borough
# Kingston upon Thames    E09000021   3726.117       0.000         F     None
# Croydon                 E09000008   8649.441       0.000         F     None
# Bromley                 E09000006  15013.487       0.000         F     None
# Hounslow                E09000018   5658.541      60.755         F     None
# Ealing                  E09000009   5554.428       0.000         F     None
# Havering                E09000016  11445.735     210.763         F     None
# Hillingdon              E09000017  11570.063       0.000         F     None
# Harrow                  E09000015   5046.330       0.000         F     None
# Brent                   E09000005   4323.270       0.000         F     None
# Barnet                  E09000003   8674.837       0.000         F     None
# Lambeth                 E09000022   2724.940      43.927         T     None
# Southwark               E09000028   2991.340     105.139         T     None
# Lewisham                E09000023   3531.706      16.795         T     None
# Greenwich               E09000011   5044.190     310.785         F     None
# Bexley                  E09000004   6428.649     370.619         F     None
# Enfield                 E09000010   8220.025       0.000         F     None
# Waltham Forest          E09000031   3880.793       0.000         F     None
# Redbridge               E09000026   5644.225       2.300         F     None
# Sutton                  E09000029   4384.698       0.000         F     None
# Richmond upon Thames    E09000027   5876.111     135.443         F     None
# Merton                  E09000024   3762.466       0.000         F     None
# Wandsworth              E09000032   3522.022      95.600         T     None
# Hammersmith and Fulham  E09000013   1715.409      75.648         T     None
# Kensington and Chelsea  E09000020   1238.379      25.994         T     None
# Westminster             E09000033   2203.005      54.308         T     None
# Camden                  E09000007   2178.932       0.000         T     None
# Tower Hamlets           E09000030   2157.501     179.707         T     None
# Islington               E09000019   1485.664       0.000         T     None
# Hackney                 E09000012   1904.902       0.000         T     None
# Haringey                E09000014   2959.837       0.000         T     None
# Newham                  E09000025   3857.806     237.637         T     None
# Barking and Dagenham    E09000002   3779.934     169.150         F     None
# City of London          E09000001    314.942      24.546         T     None
#
#                        SUB_2006  \
# borough
# Kingston upon Thames       None
# Croydon                    None
# Bromley                    None
# Hounslow                   None
# Ealing                     None
# Havering                   None
# Hillingdon                 None
# Harrow                     None
# Brent                      None
# Barnet                     None
# Lambeth                    None
# Southwark                  None
# Lewisham                   None
# Greenwich                  None
# Bexley                     None
# Enfield                    None
# Waltham Forest             None
# Redbridge                  None
# Sutton                     None
# Richmond upon Thames       None
# Merton                     None
# Wandsworth                 None
# Hammersmith and Fulham     None
# Kensington and Chelsea     None
# Westminster                None
# Camden                     None
# Tower Hamlets              None
# Islington                  None
# Hackney                    None
# Haringey                   None
# Newham                     None
# Barking and Dagenham       None
# City of London             None
#
#                                                                  geometry  \
# borough
# Kingston upon Thames    POLYGON ((516401.6 160201.8, 516407.3 160210.5...
# Croydon                 POLYGON ((535009.2 159504.7, 535005.5 159502, ...
# Bromley                 POLYGON ((540373.6 157530.4, 540361.2 157551.9...
# Hounslow                POLYGON ((521975.8 178100, 521967.7 178096.8, ...
# Ealing                  POLYGON ((510253.5 182881.6, 510249.9 182886, ...
# Havering                POLYGON ((549893.9 181459.8, 549894.6 181465.7...
# Hillingdon              POLYGON ((510599.8 191689.5, 510615.2 191591.3...
# Harrow                  POLYGON ((510599.8 191689.5, 510660 191690.9, ...
# Brent                   POLYGON ((525201 182512.6, 525181.5 182521.1, ...
# Barnet                  POLYGON ((524579.9 198355.2, 524594.3 198321.4...
# Lambeth                 POLYGON ((530046.8 177893.4, 530048.4 177894.6...
# Southwark               POLYGON ((531335.6 180529.5, 531337.7 180530.5...
# Lewisham                POLYGON ((536691 178958.6, 536691.9 178955.3, ...
# Greenwich               (POLYGON ((537238.7 178137.7, 537242.6 178136....
# Bexley                  POLYGON ((547226.2 181299.3, 547320.9 181342.4...
# Enfield                 POLYGON ((531023.5 200933.6, 531039.9 200933.9...
# Waltham Forest          POLYGON ((539923.1 191863.1, 539928.1 191846.6...
# Redbridge               POLYGON ((543595.5 184832.8, 543577.1 184837.7...
# Sutton                  POLYGON ((528552.3 159658.1, 528399.7 159928.8...
# Richmond upon Thames    POLYGON ((516677.5 175383.8, 516678.6 175378.9...
# Merton                  POLYGON ((529906.2 167417.3, 529902.2 167411.8...
# Wandsworth              POLYGON ((523489.6 176224.8, 523500.6 176218.4...
# Hammersmith and Fulham  POLYGON ((521975.8 178100, 521973 178109.8, 52...
# Kensington and Chelsea  POLYGON ((526219.7 176948, 526208.8 176960.4, ...
# Westminster             POLYGON ((528549.5 177903.8, 528542.6 177949.4...
# Camden                  POLYGON ((528840.2 187217.8, 528834.6 187205.8...
# Tower Hamlets           POLYGON ((533387.6 180516.4, 533389.8 180523.6...
# Islington               POLYGON ((529153.6 185861.4, 529144.8 185877.8...
# Hackney                 POLYGON ((531928.4 187801.5, 531935.7 187804.4...
# Haringey                POLYGON ((531928.4 187801.5, 531919.2 187797.3...
# Newham                  (POLYGON ((544065 183254.1, 544062.9 183259, 5...
# Barking and Dagenham    (POLYGON ((543905.4 183199.1, 543905 183198.9,...
# City of London          POLYGON ((531145.1 180782.1, 531143.8 180799.3...
#
#                         200801  200802  200803   ...    201603  201604  \
# borough                                          ...
# Kingston upon Thames     191.0   204.0   227.0   ...     228.0   278.0
# Croydon                  561.0   532.0   624.0   ...     784.0   827.0
# Bromley                  454.0   413.0   470.0   ...     529.0   481.0
# Hounslow                 448.0   429.0   476.0   ...     626.0   588.0
# Ealing                   596.0   599.0   625.0   ...     733.0   801.0
# Havering                 216.0   213.0   254.0   ...     502.0   487.0
# Hillingdon               480.0   488.0   508.0   ...     592.0   605.0
# Harrow                   254.0   219.0   232.0   ...     354.0   355.0
# Brent                    443.0   423.0   504.0   ...     684.0   785.0
# Barnet                   385.0   386.0   413.0   ...     576.0   634.0
# Lambeth                  603.0   628.0   604.0   ...     853.0   867.0
# Southwark                769.0   686.0   715.0   ...     742.0   763.0
# Lewisham                 638.0   663.0   740.0   ...     742.0   684.0
# Greenwich                559.0   549.0   572.0   ...     708.0   692.0
# Bexley                   238.0   301.0   286.0   ...     405.0   314.0
# Enfield                  341.0   286.0   333.0   ...     627.0   608.0
# Waltham Forest           425.0   397.0   471.0   ...     665.0   619.0
# Redbridge                318.0   327.0   387.0   ...     583.0   551.0
# Sutton                   227.0   192.0   224.0   ...     307.0   299.0
# Richmond upon Thames     144.0   151.0   160.0   ...     261.0   260.0
# Merton                   264.0   303.0   277.0   ...     373.0   325.0
# Wandsworth               433.0   385.0   433.0   ...     543.0   579.0
# Hammersmith and Fulham   389.0   421.0   380.0   ...     512.0   521.0
# Kensington and Chelsea   202.0   228.0   250.0   ...     396.0   325.0
# Westminster              713.0   617.0   648.0   ...     834.0   813.0
# Camden                   417.0   452.0   521.0   ...     619.0   598.0
# Tower Hamlets            538.0   484.0   543.0   ...     781.0   796.0
# Islington                464.0   429.0   491.0   ...     663.0   668.0
# Hackney                  520.0   524.0   592.0   ...     688.0   725.0
# Haringey                 442.0   413.0   416.0   ...     716.0   715.0
# Newham                   707.0   500.0   617.0   ...     867.0   812.0
# Barking and Dagenham     449.0   366.0   415.0   ...     557.0   475.0
# City of London             NaN     NaN     NaN   ...       NaN     NaN
#
#                         201605  201606  201607  201608  201609  201610  \
# borough
# Kingston upon Thames     262.0   268.0   281.0   278.0   296.0   259.0
# Croydon                  954.0   910.0  1021.0   914.0   891.0   904.0
# Bromley                  569.0   558.0   627.0   523.0   543.0   606.0
# Hounslow                 637.0   666.0   648.0   619.0   608.0   698.0
# Ealing                   849.0   887.0   886.0   844.0   829.0   793.0
# Havering                 532.0   558.0   535.0   482.0   515.0   480.0
# Hillingdon               709.0   679.0   748.0   673.0   644.0   669.0
# Harrow                   349.0   394.0   408.0   346.0   369.0   367.0
# Brent                    865.0   839.0   787.0   780.0   768.0   817.0
# Barnet                   711.0   677.0   666.0   661.0   658.0   677.0
# Lambeth                  998.0   926.0  1027.0   957.0   921.0   868.0
# Southwark                856.0   853.0   866.0   827.0   806.0   777.0
# Lewisham                 797.0   805.0   777.0   719.0   725.0   742.0
# Greenwich                723.0   787.0   798.0   716.0   787.0   719.0
# Bexley                   369.0   398.0   424.0   342.0   390.0   413.0
# Enfield                  724.0   682.0   679.0   613.0   640.0   647.0
# Waltham Forest           624.0   630.0   722.0   595.0   598.0   608.0
# Redbridge                568.0   558.0   612.0   588.0   508.0   523.0
# Sutton                   365.0   309.0   344.0   266.0   313.0   293.0
# Richmond upon Thames     300.0   261.0   303.0   262.0   284.0   268.0
# Merton                   385.0   362.0   418.0   349.0   341.0   314.0
# Wandsworth               611.0   587.0   690.0   510.0   586.0   629.0
# Hammersmith and Fulham   567.0   501.0   533.0   568.0   507.0   506.0
# Kensington and Chelsea   387.0   434.0   416.0   639.0   391.0   356.0
# Westminster              890.0   937.0  1152.0  1006.0   994.0   999.0
# Camden                   680.0   653.0   740.0   653.0   649.0   636.0
# Tower Hamlets            873.0   882.0   973.0   797.0   854.0   879.0
# Islington                665.0   752.0   760.0   648.0   597.0   647.0
# Hackney                  779.0   848.0   842.0   768.0   792.0   763.0
# Haringey                 826.0   753.0   821.0   744.0   730.0   720.0
# Newham                   863.0   782.0   893.0   813.0   743.0   839.0
# Barking and Dagenham     572.0   546.0   617.0   522.0   518.0   447.0
# City of London             NaN     NaN     NaN     NaN     NaN     NaN
#
#                         201611  201612
# borough
# Kingston upon Thames     247.0   296.0
# Croydon                  873.0   862.0
# Bromley                  559.0   607.0
# Hounslow                 640.0   589.0
# Ealing                   683.0   773.0
# Havering                 490.0   508.0
# Hillingdon               567.0   622.0
# Harrow                   355.0   333.0
# Brent                    736.0   777.0
# Barnet                   613.0   598.0
# Lambeth                  828.0   798.0
# Southwark                743.0   738.0
# Lewisham                 763.0   758.0
# Greenwich                679.0   696.0
# Bexley                   411.0   396.0
# Enfield                  564.0   566.0
# Waltham Forest           592.0   620.0
# Redbridge                479.0   484.0
# Sutton                   314.0   300.0
# Richmond upon Thames     251.0   249.0
# Merton                   298.0   303.0
# Wandsworth               533.0   536.0
# Hammersmith and Fulham   484.0   523.0
# Kensington and Chelsea   381.0   356.0
# Westminster              926.0  1005.0
# Camden                   593.0   675.0
# Tower Hamlets            760.0   747.0
# Islington                585.0   632.0
# Hackney                  706.0   716.0
# Haringey                 704.0   699.0
# Newham                   817.0   819.0
# Barking and Dagenham     500.0   465.0
# City of London             NaN     NaN
#
# [33 rows x 115 columns]>

# %%
# CREATE A LOOP TO MAKE MULTIPLE MAPS WITH YEAR ANNOTATIONS

# save all the maps in the charts folder
output_path = 'charts/maps'

# counter for the for loop
i = 0

# list of years (which are the column names at the moment)
list_of_years = ['200807','200907','201007','201107','201207','201307','201407','201507','201607']

# set the min and max range for the choropleth map
vmin, vmax = 200, 1200

# start the for loop to create one map per year
for year in list_of_years:
    
    # create map
    fig = merged1.plot(column=year, cmap='Blues', figsize=(10,10), linewidth=0.8, edgecolor='0.8', vmin=vmin, vmax=vmax, legend=True)
    
    # remove axis of chart
    fig.axis('off')
    
    # add a title
    fig.set_title('Violent crimes in London', \
              fontdict={'fontsize': '25',
                         'fontweight' : '3'})
    
    # create an annotation for the year
    only_year = year[:4]
    # position the annotation to the bottom left
    fig.annotate(only_year,
            xy=(0.1, .225), xycoords='figure fraction',
            horizontalalignment='left', verticalalignment='top',
            fontsize=35)
    
    # this will save the figure as a high-res png in the output path. you can also save as svg if you prefer.
    filepath = os.path.join(output_path, only_year+'_violence.jpg')
    chart = fig.get_figure()
    chart.savefig(filepath, dpi=300)
# Out:
# /Users/benjaomcooley/anaconda3/envs/maps/lib/python3.6/site-packages/matplotlib/colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-18ec6bb7dfd5> in <module>()
#      37     filepath = os.path.join(output_path, only_year+'_violence.jpg')
#      38     chart = fig.get_figure()
# ---> 39     chart.savefig(filepath, dpi=300)
#
# ~/anaconda3/envs/maps/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, fname, **kwargs)
#    2033             self.set_frameon(frameon)
#    2034
# -> 2035         self.canvas.print_figure(fname, **kwargs)
#    2036
#    2037         if frameon:
#
# ~/anaconda3/envs/maps/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2171
#    2172         # get canvas object and print method for format
# -> 2173         canvas = self._get_output_canvas(format)
#    2174         print_method = getattr(canvas, 'print_%s' % format)
#    2175
#
# ~/anaconda3/envs/maps/lib/python3.6/site-packages/matplotlib/backend_bases.py in _get_output_canvas(self, fmt)
#    2103         raise ValueError(
#    2104             "Format {!r} is not supported (supported formats: {})"
# -> 2105             .format(fmt, ", ".join(sorted(self.get_supported_filetypes()))))
#    2106
#    2107     def print_figure(self, filename, dpi=None, facecolor=None, edgecolor=None,
#
# ValueError: Format 'jpg' is not supported (supported formats: eps, pdf, pgf, png, ps, raw, rgba, svg, svgz)
